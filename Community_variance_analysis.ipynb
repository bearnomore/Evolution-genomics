# %%
import pandas as pd
import numpy as np
import glob
import matplotlib as mp
from functools import reduce

# %%
#Import all csv files of VCF 

files = glob.glob('G:\\Dropbox (Vetsigian lab)\\Vetsigian lab Team Folder\\Ye\\Genomics\\Coomunity mutants\\CMT1\\*.csv')

strain_names = list(map(lambda f: f.split('\\')[7].split('Ref')[0], files))
vcfs = list()
for (strain, file) in zip(strain_names, files):
    vcf = pd.read_csv(file)
    vcf = vcf.loc[vcf['Average Quality'] > 25]
    vcf['Variant Frequency']= list(map(lambda x: float(x[0].replace('%', ''))/100, vcf['Variant Frequency'].str.split( '->')))    
    vcf.sort_values(by = ['Variant Frequency'], ascending = False, inplace = True)
    strain_vq = vcf['Variant Frequency']
    vcf = vcf[['Name', 'Minimum', 'Maximum','Sequence','locus_tag', 'Protein Effect',  'note']]
    vcf[strain + ' VQ'] = strain_vq
    
    vcfs.append(vcf)

# %%
vcfs[0]
# Out:
#                            Name  Minimum  Maximum                    Sequence  \
# 0                             G   104233   104233                           A
# 15                       TGCGTC  6226980  6226979                      ------
# 28                            C  8612266  8612266                           A
# 27                            G  8044092  8044092                           C
# 26                            G  8004829  8004829                           A
# 25                            G  7393003  7393003                           T
# 24                            C  7364061  7364061                           G
# 23                            G  7284887  7284887                           T
# 22                            C  7261050  7261050                           G
# 21                            C  7203532  7203532                           G
# 20                            C  7183704  7183704                           G
# 19                            C  7180216  7180216                           G
# 18                            G  7146838  7146838                           A
# 17                            C  7118314  7118314                           G
# 16                            A  7084800  7084800                           C
# 1                             G   657081   657081                           T
# 14                            G  5107398  5107398                           C
# 13                            G  5044225  5044225                           C
# 12                            G  5018303  5018303                           C
# 11                            G  5018258  5018258                           C
# 10                            T  5018196  5018196                           A
# 9                             G  5017129  5017129                           C
# 8                             T  5016937  5016937                           C
# 7                             G  5016697  5016697                           A
# 6                             G  4726818  4726818                           C
# 5                             C  3667835  3667835                           G
# 4                             C  3349264  3349264                           G
# 3                            GT  1523375  1523376                          TG
# 2                             G  1415134  1415134                           C
# 29                            G  2325801  2325801                           C
# ..                          ...      ...      ...                         ...
# 97                    GGGCCGCCC  4248778  4248786                   TCTTGAGGA
# 99                            C  3054643  3054642                           -
# 100                           C  5644124  5644123                           -
# 101                       CGCAT  4863514  4863513                       -----
# 103             GGATGCCGCGCCCCG  3056137  3056136             ---------------
# 104                           G  3095247  3095246                           -
# 105                          GA  4248754  4248755                          CG
# 106                           G  8288083  8288082                           -
# 107  GTGGCGGGGCGCGGCATCCCACGGGG  3056137  3056136  --------------------------
# 108                           C  2065375  2065374                           -
# 109           CCCACCCGGACCGCGGA  4863514  4863513           -----------------
# 111                           T  4178720  4178720                           C
# 112                        GTAA  4178714  4178717                       CGT-G
# 113                           A  4178724  4178724                           G
# 114                           T  4178726  4178726                           C
# 118                          CC  4178705  4178706                          GT
# 122                           G  4178702  4178702                           C
# 123                           G  4178695  4178695                           C
# 126                           G  4178697  4178697                           C
# 130                         TTG  4178735  4178737                         CGC
# 131                           C  3048065  3048065                           T
# 140                          TT  4178690  4178691                          GA
# 143                           A  6509596  6509596                           C
# 144                           T  6140596  6140596                           C
# 145                           G  4178686  4178686                           T
# 151                           C  1346904  1346904                           T
# 155                       ACTCG  6140590  6140594                       TGCTC
# 156                          GT  6140598  6140599                          TC
# 157                          GA  4178754  4178755                          AT
# 160               GGGCGTAGGGTCG  4178739  4178751              TAC--TCCCCTCAC
#
#     locus_tag Protein Effect  \
# 0     SCO0124           None
# 15        NaN            NaN
# 28        NaN            NaN
# 27    SCO7236           None
# 26        NaN            NaN
# 25    SCO6657   Substitution
# 24    SCO6635   Substitution
# 23    SCO6578   Substitution
# 22    SCO6560   Substitution
# 21    SCO6512   Substitution
# 20    SCO6489   Substitution
# 19    SCO6487   Substitution
# 18    SCO6458   Substitution
# 17    SCO6436   Substitution
# 16    SCO6416   Substitution
# 1     SCO0617   Substitution
# 14    SCO4676           None
# 13    SCO4620           None
# 12    SCO4595           None
# 11    SCO4595           None
# 10    SCO4595   Substitution
# 9     SCO4594           None
# 8     SCO4594           None
# 7     SCO4594           None
# 6     SCO4315           None
# 5         NaN            NaN
# 4     SCO3055   Substitution
# 3     SCO1428   Substitution
# 2     SCO1337   Substitution
# 29    SCO2162   Substitution
# ..        ...            ...
# 97        NaN            NaN
# 99        NaN            NaN
# 100   SCO5186    Frame Shift
# 101       NaN            NaN
# 103       NaN            NaN
# 104       NaN            NaN
# 105       NaN            NaN
# 106       NaN            NaN
# 107       NaN            NaN
# 108       NaN            NaN
# 109       NaN            NaN
# 111   SCO3798           None
# 112   SCO3798   Substitution
# 113   SCO3798   Substitution
# 114   SCO3798           None
# 118   SCO3798   Substitution
# 122   SCO3798           None
# 123   SCO3798   Substitution
# 126   SCO3798   Substitution
# 130   SCO3798   Substitution
# 131   SCO2792   Substitution
# 140   SCO3798     Truncation
# 143   SCO5942           None
# 144   SCO5641   Substitution
# 145   SCO3798   Substitution
# 151   SCO1276   Substitution
# 155   SCO5641   Substitution
# 156   SCO5641   Substitution
# 157   SCO3798   Substitution
# 160   SCO3798   Substitution
#
#                                                   note  CMT1A2 VQ
# 0    SCJ21.05, unknown, len: 453 aa; similar in par...      1.000
# 15                                                 NaN      1.000
# 28                                                 NaN      1.000
# 27   SC7A12.03c, qcrB3, ubiquinol-cytochrome C redu...      1.000
# 26                                                 NaN      1.000
# 25   SC5A7.07c, membrane protein, len: 527 aa; simi...      1.000
# 24   SC4G2.09, pglY, len: 1294 aa; 99.8% identical ...      1.000
# 23   SC3F9.13, unknown, len: 391 aa; contains PS007...      1.000
# 22   SC4B5.10c, respiratory chain oxidoreductase, l...      1.000
# 21   SC1E6.21, probable ABC transporter ATP-binding...      1.000
# 20   SC9C7.25, conserved hypothetical protein, len:...      1.000
# 19   SC9C7.23, possible aminoacylase, len: 443aa; s...      1.000
# 18   SC9B5.25, unknown, len: 292aa; similar to TR:O...      1.000
# 17   SC9B5.03, probable tRNA synthetase, len: 506 a...      1.000
# 16   SC1A6.05, unknown, len: 340 aa; some similarit...      1.000
# 1    SCF56.01c, hypothetical protein (partial CDS),...      1.000
# 14   SCD31.01c, unknown (fragment), len: >147 aa; S...      1.000
# 13   SCD39.20c, traB1, possible sporulation-related...      1.000
# 12   SCD20.13c, probable oxidoreductase, len: 645 a...      1.000
# 11   SCD20.13c, probable oxidoreductase, len: 645 a...      1.000
# 10   SCD20.13c, probable oxidoreductase, len: 645 a...      1.000
# 9    catalyzes the coenzyme A dependent formation o...      1.000
# 8    catalyzes the coenzyme A dependent formation o...      1.000
# 7    catalyzes the coenzyme A dependent formation o...      1.000
# 6    SCD95A.48, possible homeostasis protein, len: ...      1.000
# 5                                                  NaN      1.000
# 4    SCBAC19G2.10, conserved hypothetical protein, ...      1.000
# 3    SC6D7.11, acd, acyl-CoA dehydrogenase (EC 1.3....      1.000
# 2    2SCG61.19c, possible oxidoreductase, len: 301 ...      1.000
# 29   3 different subfamilies; catalyzes the formati...      0.995
# ..                                                 ...        ...
# 97                                                 NaN      0.857
# 99                                                 NaN      0.855
# 100  2SC3B6.10, conserved hypothetical protein, len...      0.855
# 101                                                NaN      0.854
# 103                                                NaN      0.846
# 104                                                NaN      0.842
# 105                                                NaN      0.833
# 106                                                NaN      0.833
# 107                                                NaN      0.800
# 108                                                NaN      0.554
# 109                                                NaN      0.550
# 111  SCAC2.06c, possible chromosome condensation pr...      0.497
# 112  SCAC2.06c, possible chromosome condensation pr...      0.464
# 113  SCAC2.06c, possible chromosome condensation pr...      0.448
# 114  SCAC2.06c, possible chromosome condensation pr...      0.432
# 118  SCAC2.06c, possible chromosome condensation pr...      0.407
# 122  SCAC2.06c, possible chromosome condensation pr...      0.371
# 123  SCAC2.06c, possible chromosome condensation pr...      0.350
# 126  SCAC2.06c, possible chromosome condensation pr...      0.341
# 130  SCAC2.06c, possible chromosome condensation pr...      0.330
# 131  SCC105.23, adpA, araC-family transcriptional r...      0.323
# 140  SCAC2.06c, possible chromosome condensation pr...      0.282
# 143  SC7H1.12, unknown, len: 205 aa; very weak simi...      0.280
# 144  SC6A9.26, probable transposase for IS1649, len...      0.277
# 145  SCAC2.06c, possible chromosome condensation pr...      0.276
# 151  2SCG18.23, sigJ, RNA polymerase ECF sigma fact...      0.260
# 155  SC6A9.26, probable transposase for IS1649, len...      0.255
# 156  SC6A9.26, probable transposase for IS1649, len...      0.255
# 157  SCAC2.06c, possible chromosome condensation pr...      0.251
# 160  SCAC2.06c, possible chromosome condensation pr...      0.229
#
# [119 rows x 8 columns]

# %%
df1 = vcfs[0]
df2 = vcfs[1]
print(len(df1), len(df2))
# Out:
# 119 141

# %%
df_m = df1.merge(df2, on = ['Name', 'Minimum', 'Maximum','Sequence','locus_tag', 'Protein Effect', 'note'], how = 'outer')

# %%
df_m
# Out:
#                               Name  Minimum  Maximum  \
# 0                                G   104233   104233
# 1                           TGCGTC  6226980  6226979
# 2                                C  8612266  8612266
# 3                                G  8044092  8044092
# 4                                G  8004829  8004829
# 5                                G  7393003  7393003
# 6                                C  7364061  7364061
# 7                                G  7284887  7284887
# 8                                C  7261050  7261050
# 9                                C  7203532  7203532
# 10                               C  7183704  7183704
# 11                               C  7180216  7180216
# 12                               G  7146838  7146838
# 13                               C  7118314  7118314
# 14                               A  7084800  7084800
# 15                               G   657081   657081
# 16                               G  5107398  5107398
# 17                               G  5044225  5044225
# 18                               G  5018303  5018303
# 19                               G  5018258  5018258
# 20                               T  5018196  5018196
# 21                               G  5017129  5017129
# 22                               T  5016937  5016937
# 23                               G  5016697  5016697
# 24                               G  4726818  4726818
# 25                               C  3667835  3667835
# 26                               C  3349264  3349264
# 27                              GT  1523375  1523376
# 28                               G  1415134  1415134
# 29                               G  2325801  2325801
# ..                             ...      ...      ...
# 138                           ACCG  4863514  4863513
# 139                           GTAA  4178714  4178717
# 140  TCCGCCGCCCCGCGCGGCCGCATGCGGGG  4863514  4863513
# 141                   ACCGCGGGTCCG  4863514  4863513
# 142                  ACCGCGGAAAGGT  4863514  4863513
# 143                     GCCCACCCGG  4863514  4863513
# 144                              G  8267245  8267245
# 145                              C  6140609  6140609
# 146                             CT  6140603  6140604
# 147                              T  7062677  7062677
# 148                              T  7342678  7342678
# 149                              T  8267244  8267244
# 150                              C  6140563  6140563
# 151                            ACT  4178708  4178710
# 152                             GT  6140574  6140575
# 153                         TACTCG  6140589  6140594
# 154                        ACGTAAC  6140578  6140584
# 155                              A  6140553  6140553
# 156                              G  4178688  4178688
# 157                              T  6140572  6140572
# 158                            CCA  4178705  4178707
# 159                             GC  6140568  6140569
# 160                              G  4178683  4178683
# 161                             AG  4178685  4178686
# 162                             GT  4178702  4178703
# 163                              C  4178703  4178703
# 164                              A  4178701  4178701
# 165                              C  7062700  7062700
# 166                            ACG  6140557  6140559
# 167                  GGGCGTAGGGTCG  4178739  4178751
#
#                           Sequence locus_tag Protein Effect  \
# 0                                A   SCO0124           None
# 1                           ------       NaN            NaN
# 2                                A       NaN            NaN
# 3                                C   SCO7236           None
# 4                                A       NaN            NaN
# 5                                T   SCO6657   Substitution
# 6                                G   SCO6635   Substitution
# 7                                T   SCO6578   Substitution
# 8                                G   SCO6560   Substitution
# 9                                G   SCO6512   Substitution
# 10                               G   SCO6489   Substitution
# 11                               G   SCO6487   Substitution
# 12                               A   SCO6458   Substitution
# 13                               G   SCO6436   Substitution
# 14                               C   SCO6416   Substitution
# 15                               T   SCO0617   Substitution
# 16                               C   SCO4676           None
# 17                               C   SCO4620           None
# 18                               C   SCO4595           None
# 19                               C   SCO4595           None
# 20                               A   SCO4595   Substitution
# 21                               C   SCO4594           None
# 22                               C   SCO4594           None
# 23                               A   SCO4594           None
# 24                               C   SCO4315           None
# 25                               G       NaN            NaN
# 26                               G   SCO3055   Substitution
# 27                              TG   SCO1428   Substitution
# 28                               C   SCO1337   Substitution
# 29                               C   SCO2162   Substitution
# ..                             ...       ...            ...
# 138                           ----       NaN            NaN
# 139                           CGTG   SCO3798   Substitution
# 140  -----------------------------       NaN            NaN
# 141                   ------------       NaN            NaN
# 142                  -------------       NaN            NaN
# 143                     ----------       NaN            NaN
# 144                              A       NaN            NaN
# 145                              G   SCO5641   Substitution
# 146                             GC   SCO5641   Substitution
# 147                              G       NaN            NaN
# 148                              C   SCO6621   Substitution
# 149                              A   SCO7451      Extension
# 150                              A   SCO5641   Substitution
# 151                             CA   SCO3798   Substitution
# 152                             TA   SCO5641   Substitution
# 153                         GTGCTC   SCO5641   Substitution
# 154                        GGCCCGA   SCO5641   Substitution
# 155                              G   SCO5641           None
# 156                              T   SCO3798   Substitution
# 157                              C   SCO5641   Substitution
# 158                            GTG   SCO3798   Substitution
# 159                             CA   SCO5641   Substitution
# 160                              C   SCO3798   Substitution
# 161                             GT   SCO3798   Substitution
# 162                             CG   SCO3798   Substitution
# 163                              G   SCO3798   Substitution
# 164                              G   SCO3798   Substitution
# 165                              T       NaN            NaN
# 166                            CAT   SCO5641   Substitution
# 167                  TACTCCC-CTCAC   SCO3798   Substitution
#
#                                                   note  CMT1A2 VQ  CMT1B2 VQ
# 0    SCJ21.05, unknown, len: 453 aa; similar in par...      1.000      0.976
# 1                                                  NaN      1.000        NaN
# 2                                                  NaN      1.000      1.000
# 3    SC7A12.03c, qcrB3, ubiquinol-cytochrome C redu...      1.000      0.982
# 4                                                  NaN      1.000      1.000
# 5    SC5A7.07c, membrane protein, len: 527 aa; simi...      1.000      0.966
# 6    SC4G2.09, pglY, len: 1294 aa; 99.8% identical ...      1.000      1.000
# 7    SC3F9.13, unknown, len: 391 aa; contains PS007...      1.000      0.982
# 8    SC4B5.10c, respiratory chain oxidoreductase, l...      1.000      1.000
# 9    SC1E6.21, probable ABC transporter ATP-binding...      1.000      1.000
# 10   SC9C7.25, conserved hypothetical protein, len:...      1.000      1.000
# 11   SC9C7.23, possible aminoacylase, len: 443aa; s...      1.000      1.000
# 12   SC9B5.25, unknown, len: 292aa; similar to TR:O...      1.000      1.000
# 13   SC9B5.03, probable tRNA synthetase, len: 506 a...      1.000      0.982
# 14   SC1A6.05, unknown, len: 340 aa; some similarit...      1.000      0.952
# 15   SCF56.01c, hypothetical protein (partial CDS),...      1.000      1.000
# 16   SCD31.01c, unknown (fragment), len: >147 aa; S...      1.000      0.992
# 17   SCD39.20c, traB1, possible sporulation-related...      1.000      0.984
# 18   SCD20.13c, probable oxidoreductase, len: 645 a...      1.000      0.987
# 19   SCD20.13c, probable oxidoreductase, len: 645 a...      1.000      0.986
# 20   SCD20.13c, probable oxidoreductase, len: 645 a...      1.000      1.000
# 21   catalyzes the coenzyme A dependent formation o...      1.000        NaN
# 22   catalyzes the coenzyme A dependent formation o...      1.000      0.989
# 23   catalyzes the coenzyme A dependent formation o...      1.000      1.000
# 24   SCD95A.48, possible homeostasis protein, len: ...      1.000      0.991
# 25                                                 NaN      1.000      1.000
# 26   SCBAC19G2.10, conserved hypothetical protein, ...      1.000      0.993
# 27   SC6D7.11, acd, acyl-CoA dehydrogenase (EC 1.3....      1.000      0.954
# 28   2SCG61.19c, possible oxidoreductase, len: 301 ...      1.000      0.987
# 29   3 different subfamilies; catalyzes the formati...      0.995      0.993
# ..                                                 ...        ...        ...
# 138                                                NaN        NaN      0.563
# 139  SCAC2.06c, possible chromosome condensation pr...        NaN      0.551
# 140                                                NaN        NaN      0.447
# 141                                                NaN        NaN      0.412
# 142                                                NaN        NaN      0.409
# 143                                                NaN        NaN      0.395
# 144                                                NaN        NaN      0.350
# 145  SC6A9.26, probable transposase for IS1649, len...        NaN      0.346
# 146  SC6A9.26, probable transposase for IS1649, len...        NaN      0.333
# 147                                                NaN        NaN      0.320
# 148  SC1F2.18, unknown, len: 424 aa; some similarit...        NaN      0.305
# 149  SC5C11.08, unknown, len: 398 aa. Highly simila...        NaN      0.300
# 150  SC6A9.26, probable transposase for IS1649, len...        NaN      0.294
# 151  SCAC2.06c, possible chromosome condensation pr...        NaN      0.282
# 152  SC6A9.26, probable transposase for IS1649, len...        NaN      0.281
# 153  SC6A9.26, probable transposase for IS1649, len...        NaN      0.279
# 154  SC6A9.26, probable transposase for IS1649, len...        NaN      0.279
# 155  SC6A9.26, probable transposase for IS1649, len...        NaN      0.277
# 156  SCAC2.06c, possible chromosome condensation pr...        NaN      0.268
# 157  SC6A9.26, probable transposase for IS1649, len...        NaN      0.259
# 158  SCAC2.06c, possible chromosome condensation pr...        NaN      0.256
# 159  SC6A9.26, probable transposase for IS1649, len...        NaN      0.255
# 160  SCAC2.06c, possible chromosome condensation pr...        NaN      0.253
# 161  SCAC2.06c, possible chromosome condensation pr...        NaN      0.253
# 162  SCAC2.06c, possible chromosome condensation pr...        NaN      0.251
# 163  SCAC2.06c, possible chromosome condensation pr...        NaN      0.251
# 164  SCAC2.06c, possible chromosome condensation pr...        NaN      0.250
# 165                                                NaN        NaN      0.250
# 166  SC6A9.26, probable transposase for IS1649, len...        NaN      0.240
# 167  SCAC2.06c, possible chromosome condensation pr...        NaN      0.229
#
# [168 rows x 9 columns]

# %%
col_names  = vcfs[0].columns.values
df = vcfs[0]
for df in vcfs[1:]:
    df_ = df_.merge(df, on= col_names)

# %%
# Simplify the vcfs by selecting columns 'Name', 'Minimum', 'Maximum', 'Sequence', 'Variant Frequency', 'locus_tag', 'note'
cols = ['Name', 'Minimum', 'Maximum', 'Sequence', 'Variant Frequency', 'locus_tag', 'note']
def simplify_vcfs(vcfs, cols):
    vcfs_s = dict()
    for key in vcfs:
        vcfs_s[key] = vcfs[key].loc[:, cols]
    return vcfs_s

# %%
vcfs_s = simplify_vcfs(vcfs,cols)
vcfs_s[strain_names[1]]
# Out:
#               Name  Minimum  Maximum       Sequence  Variant Frequency  \
# 0                G   619978   619978              C              1.000
# 13               G  7044234  7044234              A              1.000
# 23               C  8612266  8612266              A              1.000
# 22               G  8595557  8595557              C              1.000
# 21               C  8594044  8594044              T              1.000
# 20               G  8004829  8004829              A              1.000
# 19               C  7364061  7364061              G              1.000
# 18               C  7261050  7261050              G              1.000
# 1                G   657081   657081              T              1.000
# 16               C  7183704  7183704              G              1.000
# 15               C  7180216  7180216              G              1.000
# 14               G  7146838  7146838              A              1.000
# 17               C  7203532  7203532              G              1.000
# 12               G  6008595  6008595              T              1.000
# 6                C  3667835  3667835              G              1.000
# 11               T  5018196  5018196              A              1.000
# 3                G  2533425  2533425              A              1.000
# 4              CCG  3056137  3056136            ---              1.000
# 5                G  3348967  3348967              C              1.000
# 2                C  1644238  1644238              A              1.000
# 7                C  3680393  3680393              A              1.000
# 8                C  4248813  4248813              G              1.000
# 9                G  5016697  5016697              A              1.000
# 10               G  5017102  5017102              C              1.000
# 24               G  2325801  2325801              C              0.993
# 25               C  3349264  3349264              G              0.993
# 26               G  5107398  5107398              C              0.992
# 27               G  4726818  4726818              C              0.991
# 28               T  1622503  1622503              A              0.989
# 29              GC  1644332  1644333             CG              0.989
# ..             ...      ...      ...            ...                ...
# 133              T  4178726  4178726              C              0.374
# 137              G  8267245  8267245              A              0.350
# 140              C  6140609  6140609              G              0.346
# 141             TT  4178690  4178691             GA              0.345
# 143             CT  6140603  6140604             GC              0.333
# 147              T  6140596  6140596              C              0.324
# 150            TTG  4178735  4178737            CGC              0.321
# 151              T  7062677  7062677              G              0.320
# 154             GT  6140598  6140599             TC              0.306
# 155              T  7342678  7342678              C              0.305
# 158              T  8267244  8267244              A              0.300
# 160              C  6140563  6140563              A              0.294
# 164            ACT  4178708  4178710             CA              0.282
# 165             GT  6140574  6140575             TA              0.281
# 166         TACTCG  6140589  6140594         GTGCTC              0.279
# 167        ACGTAAC  6140578  6140584        GGCCCGA              0.279
# 169              A  6140553  6140553              G              0.277
# 175              G  4178688  4178688              T              0.268
# 184              T  6140572  6140572              C              0.259
# 185            CCA  4178705  4178707            GTG              0.256
# 186             GC  6140568  6140569             CA              0.255
# 187              G  4178683  4178683              C              0.253
# 188             AG  4178685  4178686             GT              0.253
# 189             GT  4178702  4178703             CG              0.251
# 190              C  4178703  4178703              G              0.251
# 191              A  4178701  4178701              G              0.250
# 193              C  7062700  7062700              T              0.250
# 194             GA  4178754  4178755             AT              0.246
# 195            ACG  6140557  6140559            CAT              0.240
# 196  GGGCGTAGGGTCG  4178739  4178751  TACTCCC-CTCAC              0.229
#
#     locus_tag                                               note
# 0     SCO0578  SCF55.02c, possible triosephosphate isomerase,...
# 13    SCO6381  SC4A2.17c, probable lipoprotein, len: 447 aa; ...
# 23        NaN                                                NaN
# 22    SCO7766  SC5E9.14, conserved hypothetical protein, len:...
# 21    SCO7763  SC5E9.11, possible membrane protein, len: 233a...
# 20        NaN                                                NaN
# 19    SCO6635  SC4G2.09, pglY, len: 1294 aa; 99.8% identical ...
# 18    SCO6560  SC4B5.10c, respiratory chain oxidoreductase, l...
# 1     SCO0617  SCF56.01c, hypothetical protein (partial CDS),...
# 16    SCO6489  SC9C7.25, conserved hypothetical protein, len:...
# 15    SCO6487  SC9C7.23, possible aminoacylase, len: 443aa; s...
# 14    SCO6458  SC9B5.25, unknown, len: 292aa; similar to TR:O...
# 17    SCO6512  SC1E6.21, probable ABC transporter ATP-binding...
# 12    SCO5516  SC8D9.28c, probable integral membrane efflux p...
# 6         NaN                                                NaN
# 11    SCO4595  SCD20.13c, probable oxidoreductase, len: 645 a...
# 3         NaN                                                NaN
# 4         NaN                                                NaN
# 5     SCO3055  SCBAC19G2.10, conserved hypothetical protein, ...
# 2     SCO1536  SCL2.26c, hypothetical protein, len: 822 aa; s...
# 7         NaN                                                NaN
# 8     SCO3864  SCH18.01, probable transcriptional regulator (...
# 9     SCO4594  catalyzes the coenzyme A dependent formation o...
# 10    SCO4594  catalyzes the coenzyme A dependent formation o...
# 24    SCO2162  3 different subfamilies; catalyzes the formati...
# 25    SCO3055  SCBAC19G2.10, conserved hypothetical protein, ...
# 26    SCO4676  SCD31.01c, unknown (fragment), len: >147 aa; S...
# 27    SCO4315  SCD95A.48, possible homeostasis protein, len: ...
# 28    SCO1516  part of the preprotein secretory system; when ...
# 29    SCO1536  SCL2.26c, hypothetical protein, len: 822 aa; s...
# ..        ...                                                ...
# 133   SCO3798  SCAC2.06c, possible chromosome condensation pr...
# 137       NaN                                                NaN
# 140   SCO5641  SC6A9.26, probable transposase for IS1649, len...
# 141   SCO3798  SCAC2.06c, possible chromosome condensation pr...
# 143   SCO5641  SC6A9.26, probable transposase for IS1649, len...
# 147   SCO5641  SC6A9.26, probable transposase for IS1649, len...
# 150   SCO3798  SCAC2.06c, possible chromosome condensation pr...
# 151       NaN                                                NaN
# 154   SCO5641  SC6A9.26, probable transposase for IS1649, len...
# 155   SCO6621  SC1F2.18, unknown, len: 424 aa; some similarit...
# 158   SCO7451  SC5C11.08, unknown, len: 398 aa. Highly simila...
# 160   SCO5641  SC6A9.26, probable transposase for IS1649, len...
# 164   SCO3798  SCAC2.06c, possible chromosome condensation pr...
# 165   SCO5641  SC6A9.26, probable transposase for IS1649, len...
# 166   SCO5641  SC6A9.26, probable transposase for IS1649, len...
# 167   SCO5641  SC6A9.26, probable transposase for IS1649, len...
# 169   SCO5641  SC6A9.26, probable transposase for IS1649, len...
# 175   SCO3798  SCAC2.06c, possible chromosome condensation pr...
# 184   SCO5641  SC6A9.26, probable transposase for IS1649, len...
# 185   SCO3798  SCAC2.06c, possible chromosome condensation pr...
# 186   SCO5641  SC6A9.26, probable transposase for IS1649, len...
# 187   SCO3798  SCAC2.06c, possible chromosome condensation pr...
# 188   SCO3798  SCAC2.06c, possible chromosome condensation pr...
# 189   SCO3798  SCAC2.06c, possible chromosome condensation pr...
# 190   SCO3798  SCAC2.06c, possible chromosome condensation pr...
# 191   SCO3798  SCAC2.06c, possible chromosome condensation pr...
# 193       NaN                                                NaN
# 194   SCO3798  SCAC2.06c, possible chromosome condensation pr...
# 195   SCO5641  SC6A9.26, probable transposase for IS1649, len...
# 196   SCO3798  SCAC2.06c, possible chromosome condensation pr...
#
# [141 rows x 7 columns]

# %%
#Find all variance in mutants with 100% Variant Frquency 
def diff2ref_100_in_mutants(vcfs_s):
    '''
    input: vcfs_s, dictionary of simplified variant files of all mutants and WT compared to the ref genome;
           
    output: dictionary of variant files of mutants with 100% variant freq, the WT file is unchanged
    '''
    vcfs_100 =  dict()
    for key in vcfs_s:
        vcf = vcfs_s[key]
        vcf['locus_tag'].fillna('intergenetic region', inplace = True)
        if key != 'WT':
            vcfs_100[key] = vcf[vcf['Variant Frequency'] == 1].set_index(['Minimum', 'Maximum', 'Name'])
        else:
            vcfs_100[key] = vcf.set_index(['Minimum', 'Maximum', 'Name'])
    return vcfs_100

# %%
vcfs_100 = diff2ref_100_in_mutants(vcfs_s)
vcfs_100[strain_names[1]]
# Out:
#                      Sequence  Variant Frequency            locus_tag  \
# Minimum Maximum Name
# 619978  619978  G           C                1.0              SCO0578
# 7044234 7044234 G           A                1.0              SCO6381
# 8612266 8612266 C           A                1.0  intergenetic region
# 8595557 8595557 G           C                1.0              SCO7766
# 8594044 8594044 C           T                1.0              SCO7763
# 8004829 8004829 G           A                1.0  intergenetic region
# 7364061 7364061 C           G                1.0              SCO6635
# 7261050 7261050 C           G                1.0              SCO6560
# 657081  657081  G           T                1.0              SCO0617
# 7183704 7183704 C           G                1.0              SCO6489
# 7180216 7180216 C           G                1.0              SCO6487
# 7146838 7146838 G           A                1.0              SCO6458
# 7203532 7203532 C           G                1.0              SCO6512
# 6008595 6008595 G           T                1.0              SCO5516
# 3667835 3667835 C           G                1.0  intergenetic region
# 5018196 5018196 T           A                1.0              SCO4595
# 2533425 2533425 G           A                1.0  intergenetic region
# 3056137 3056136 CCG       ---                1.0  intergenetic region
# 3348967 3348967 G           C                1.0              SCO3055
# 1644238 1644238 C           A                1.0              SCO1536
# 3680393 3680393 C           A                1.0  intergenetic region
# 4248813 4248813 C           G                1.0              SCO3864
# 5016697 5016697 G           A                1.0              SCO4594
# 5017102 5017102 G           C                1.0              SCO4594
#
#                                                                    note
# Minimum Maximum Name
# 619978  619978  G     SCF55.02c, possible triosephosphate isomerase,...
# 7044234 7044234 G     SC4A2.17c, probable lipoprotein, len: 447 aa; ...
# 8612266 8612266 C                                                   NaN
# 8595557 8595557 G     SC5E9.14, conserved hypothetical protein, len:...
# 8594044 8594044 C     SC5E9.11, possible membrane protein, len: 233a...
# 8004829 8004829 G                                                   NaN
# 7364061 7364061 C     SC4G2.09, pglY, len: 1294 aa; 99.8% identical ...
# 7261050 7261050 C     SC4B5.10c, respiratory chain oxidoreductase, l...
# 657081  657081  G     SCF56.01c, hypothetical protein (partial CDS),...
# 7183704 7183704 C     SC9C7.25, conserved hypothetical protein, len:...
# 7180216 7180216 C     SC9C7.23, possible aminoacylase, len: 443aa; s...
# 7146838 7146838 G     SC9B5.25, unknown, len: 292aa; similar to TR:O...
# 7203532 7203532 C     SC1E6.21, probable ABC transporter ATP-binding...
# 6008595 6008595 G     SC8D9.28c, probable integral membrane efflux p...
# 3667835 3667835 C                                                   NaN
# 5018196 5018196 T     SCD20.13c, probable oxidoreductase, len: 645 a...
# 2533425 2533425 G                                                   NaN
# 3056137 3056136 CCG                                                 NaN
# 3348967 3348967 G     SCBAC19G2.10, conserved hypothetical protein, ...
# 1644238 1644238 C     SCL2.26c, hypothetical protein, len: 822 aa; s...
# 3680393 3680393 C                                                   NaN
# 4248813 4248813 C     SCH18.01, probable transcriptional regulator (...
# 5016697 5016697 G     catalyzes the coenzyme A dependent formation o...
# 5017102 5017102 G     catalyzes the coenzyme A dependent formation o...

# %%
# Find all 100% appeared variance in mutant strains, pick up the 'Minimum', 'Maximum' and 'Name' as the mark for the variance
def find_diff_100(vcfs_100):
    '''
    input: simplified vcfs with difference 100% appeared in mutants
    output: diff, all nonredundant diff in all mutants;
    '''
    strains = list(vcfs_100.keys())
    df = vcfs_100[strains[0]]
    for strain in strains[1:-1]:
        df = df.append(vcfs_100[strain])
    return list(set(df.index.values))

# %%
diff = find_diff_100(vcfs_100)
diff[0]

# %%
variance_table = pd.DataFrame(index = diff, columns = strain_names)
variance_table['WT VF'] = np.nan
for strain in strain_names:
    vcf = vcfs_100[strain]
    strain_inds = vcf.index.values
    if strain != 'WT':
        for ind in strain_inds:
            if ind in diff:
                variance_table.loc[ind, strain] = 1            
    else:
        for ind in strain_inds:
            # For WT strain, there are two cases:
            # Case one: the exactly the same diff (locus and change) in WT is found in mutants-- preexisted change didn't evolve 
            # Case two: the diff site in WT is the same as in mutants, but the change is different-- preexisted change evolve again in mutants
            for d in diff:
                if ind == d:
                    variance_table.loc[d,'WT VF'] = round(vcf.loc[ind, 'Variant Frequency'], 2)
                    variance_table.loc[d, strain] = 1   
                elif ind[0:2] == d[0:2] and ind[2] != vcf.loc[ind, 'Sequence']:
                    variance_table.loc[d,'WT VF'] = round(vcf.loc[ind, 'Variant Frequency'], 2)
                    variance_table.loc[d, strain] = 1
                          
variance_table = variance_table.fillna(0).sort_index()

# %%
# save variance_table as csv
filepath = "G:\\Ye\\Evolution mutants\\variance_table.csv"
cols = variance_table.columns.values
df = variance_table.loc[:, cols[:-2]]
df.to_csv(filepath)
df

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn2

# %%
def venn_WT_Mutant(variance_table, mutant_name):
    comp_table = variance_table[[mutant_name, 'WT']]
    strain_num = comp_table.aggregate('sum')
    common_diff_num = sum(comp_table.sum(axis = 1) == 2)
    venn2(subsets = (strain_num[mutant_name], strain_num['WT'], common_diff_num), set_labels = (mutant_name, 'WT'))
    plt.show()

# %%
venn_WT_Mutant(variance_table, 'R5')

# %%
from scipy.spatial.distance import squareform, pdist
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import linkage
cols = variance_table.columns.values
df = variance_table.loc[:, cols[0:-2]].transpose()
Y = pdist(df, 'euclidean')
dist_mat = squareform(Y)
linkage_matrix = linkage(dist_mat, "single")
dendrogram(linkage_matrix, color_threshold=1, labels=cols[0:-2],show_leaf_counts=True, leaf_rotation = 45)
plt.title=("test")
plt.show()

# %%
import rpy2.robjects as robjects
from rpy2.robjects.packages import importr
base = importr("base")
pvclust = importr("pvclust")
data = robjects.DataFrame.from_csvfile("G:\\Ye\\Evolution mutants\\variance_table.csv")
#result = pvclust.pvclust(df, nboot=100, method_dist="correlation", method_hclust="average")

data.head(5)
cols = robjects.IntVector(range(2,17))

subset = data.rx(True, cols)
subset.head(5)
result = pvclust.pvclust(subset, nboot=1000, method_dist="correlation", method_hclust="single")

# %%
graphics = importr("graphics")
grdevices = importr("grDevices")
#grdevices.pdf("G:\\Ye\\Evolution mutants\\evolveMutants_phylo_boot1000.pdf", paper="a4")
graphics.plot(result)
#grdevices.dev_off()

# %%
def find_variance_by_mutant(variance_table, mutant_name):
    variance = variance_table[mutant_name].where(variance_table[mutant_name] == 1).dropna().index.values
    variance = vcfs_100[mutant_name].loc[variance, ['locus_tag', 'note']]
    variance_genes = variance.dropna().reset_index(drop = True).set_index('locus_tag').drop_duplicates()
    return variance, variance_genes

# %%
# Only look at genes
variance_full, variance_genes = find_variance_by_mutant(variance_table, 'WT') 
variance_full

# %%
def find_hot_variance(variance_table, hot_thresh):
    cols = variance_table.columns.values
    df = variance_table.loc[:, cols[:-2]]
    hits = df.sum(axis = 1).sort_values(ascending = False) 
    hot_variance = hits[hits >= hot_thresh].index.values
    return hot_variance

# %%
def find_hot_variance_by_mutant(variance_table, mutant_name, hot_thresh):
    hots = find_hot_variance(variance_table,hot_thresh)
    variance_full, variance_genes = find_variance_by_mutant(variance_table, mutant_name) 
    var_mutant = variance_full.index.values
    intersection = list(set(hots).intersection(var_mutant))
    hots_mut = variance_full.loc[intersection, ['locus_tag', 'note']]
    return hots_mut.dropna()[['locus_tag', 'note']].drop_duplicates().sort_values(by = 'locus_tag')

# %%
find_hot_variance_by_mutant(variance_table, 'W2', 10)

# %%
def find_cold_variance(variance_table, cold_thresh):
    cols = variance_table.columns.values
    df = variance_table.loc[:, cols[:-2]]
    hits = df.sum(axis = 1).sort_values(ascending = False) 
    cold_variance = hits[hits < cold_thresh].index.values
    return cold_variance

# %%
def find_cold_variance_by_mutant(variance_table, mutant_name, cold_thresh):
    colds = find_cold_variance(variance_table,cold_thresh)
    variance_full, variance_genes = find_variance_by_mutant(variance_table, mutant_name) 
    var_mutant = variance_full.index.values
    intersection = list(set(colds).intersection(var_mutant))
    colds_mut = variance_full.loc[intersection, ['locus_tag', 'note']]
    return colds_mut.dropna()[['locus_tag', 'note']].drop_duplicates().sort_values(by = 'locus_tag')

# %%
find_cold_variance_by_mutant(variance_table, 'W2', 3)

# %%
# Read pathway cluster file 
pathways = pd.read_excel("G:\\Ye\\Evolution mutants\\Gene clusters in coelicolor.xlsx")
pathways.head(5)

# %%
pathways_coe = pathways.drop(2).reset_index()

# %%
locations = pathways_coe['Location'].apply(str).str.split('—')
short_inds = locations[locations.apply(len) == 1].index.values
for pos in short_inds:
    val = int(locations.iloc[pos][0])
    locations.iloc[pos] = [val, val]

# %%
pathways_coe['location'] = locations
pathways_coe = pathways_coe.drop(columns = ['index', 'Location'])

# %%
pathways_coe

# %%
pathways_coe.loc[0,'location']

# %%
variance_R1 = find_hot_variance_by_mutant(variance_table, 'R1', 1)
locus_R1 = variance_R1['locus_tag'].str.lstrip('SCO')
locus_ranges = pathways_coe['location']
for pos in locus_R1:
    pos = int(pos)
    for locus in locus_ranges:
        if pos in range(int(locus[0]), int(locus[1])):
            print(locus, pos)

# %%
def find_pathway_hits(variance_table, mutant_name, hot_thresh, pathways_coe):
    variance_mut = find_hot_variance_by_mutant(variance_table, mutant_name, hot_thresh)
    locus_mut = variance_mut['locus_tag'].str.lstrip('SCO')
    locus_ranges = pathways_coe['location']
    for pos in locus_mut:
        pos = int(pos)
        for locus in locus_ranges:
            if pos in range(int(locus[0]), int(locus[1])):
                print(locus, pos)

# %%
find_pathway_hits(variance_table, 'WS2', 1, pathways_coe)
